# %% [markdown]
# # **Primera Entrega | Trabajo Final | Coderhouse: Uncal, Juan Martin**
#
# Fuente de Datos: Kaggle (Airbnb Europa)
# Se compone de 20 cvs con los datos de las principales capitales de Europa
#
# El proyecto se enfoca en el análisis del costo de las propiedades de Airbnb en las principales ciudades de Europa. El dataset utilizado fue obtenido de una base de datos, que contiene información detallada sobre diversas características de las propiedades, como el tipo de habitación, la capacidad de personas, la ubicación geográfica, las valoraciones de los huéspedes, entre otros.
#
# El objetivo principal del proyecto es desarrollar modelos de regresión y clasificación para predecir los precios y valoraciones de las propiedades de Airbnb, respectivamente. Para ello, se aplican técnicas de selección de características utilizando Recursive Feature Elimination (RFE) y se utilizan algoritmos como Random Forest para construir los modelos.
#
# El análisis se centra en evaluar el rendimiento de los modelos en términos de su capacidad predictiva y la precisión de las características seleccionadas. Además, se calculan métricas como el MAE (Error Absoluto Medio) para evaluar la precisión de las predicciones de precios y el recall para evaluar el rendimiento del modelo de clasificación.
#
# El proyecto proporciona una visión general de los factores que influyen en el costo de las propiedades de Airbnb en Europa y ofrece una perspectiva sobre la capacidad de los modelos para predecir los precios y valoraciones de estas propiedades. Esto puede ser útil para entender el mercado inmobiliario de alquileres a corto plazo y tomar decisiones informadas en la industria turística y hotelera.
#
#
# El objetivo de este análisis es proporcionar información sobre las propiedades de Airbnb en las principales ciudades de Europa, centrándose en dos aspectos principales: la relación entre los precios y la capacidad de las propiedades, y la relación entre los precios y la puntuación de satisfacción de los huéspedes.
#
# **Problema Comercial:**
# El problema comercial que se aborda es entender cómo se relacionan los precios de las propiedades de Airbnb con su capacidad y la satisfacción de los huéspedes. Esto puede ayudar a los propietarios y administradores de propiedades a tomar decisiones informadas sobre los precios, así como a los viajeros a tener una idea de qué esperar en términos de relación calidad-precio.
#
# **Contexto Analítico:**
# El contexto analítico se centra en el análisis de las bases de datos de Airbnb en las principales ciudades de Europa. Se recopilarán datos sobre las propiedades, incluyendo su capacidad (número de huéspedes que pueden alojar) y su puntuación de satisfacción. Además, se obtendrán datos sobre los precios de estas propiedades. El análisis se realizará utilizando técnicas de ciencia de datos para identificar patrones y tendencias en los datos.

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/AirbnbEurope'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/AirbnbEurope

# %%
import pandas as pd
import glob

path = '/content/gdrive/MyDrive/AirbnbEurope'
all_files = glob.glob(path + "/*.csv")

data_frames = []

for file in all_files:
    df = pd.read_csv(file)
    data_frames.append(df)

# %%
import matplotlib.pyplot as plt
# !pip install pingouin
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels
from scipy import stats
from pingouin import pairwise_ttests
import pandas as pd
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pingouin
#   Downloading pingouin-0.5.3-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from pingouin) (1.22.4)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from pingouin) (1.10.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from pingouin) (1.5.3)
# Requirement already satisfied: matplotlib>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from pingouin) (3.7.1)
# Requirement already satisfied: seaborn>=0.11 in /usr/local/lib/python3.10/dist-packages (from pingouin) (0.12.2)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from pingouin) (0.13.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pingouin) (1.2.2)
# Collecting pandas-flavor>=0.2.0 (from pingouin)
#   Downloading pandas_flavor-0.5.0-py3-none-any.whl (7.1 kB)
# Collecting outdated (from pingouin)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pingouin) (0.8.10)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->pingouin) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->pingouin) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->pingouin) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->pingouin) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->pingouin) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->pingouin) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->pingouin) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->pingouin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->pingouin) (2022.7.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pandas-flavor>=0.2.0->pingouin) (2022.12.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from pandas-flavor>=0.2.0->pingouin) (0.2)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13->pingouin) (0.5.3)
# Requirement already satisfied: setuptools>=44 in /usr/local/lib/python3.10/dist-packages (from outdated->pingouin) (67.7.2)
# Collecting littleutils (from outdated->pingouin)
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from outdated->pingouin) (2.27.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pingouin) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pingouin) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.13->pingouin) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->outdated->pingouin) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->outdated->pingouin) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->outdated->pingouin) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->outdated->pingouin) (3.4)
# Building wheels for collected packages: littleutils
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7029 sha256=f15a29ebf5b74fe674439322eb3169083d141e301476cced3b59f1260b2b5cbf
#   Stored in directory: /root/.cache/pip/wheels/3d/fe/b0/27a9892da57472e538c7452a721a9cf463cc03cf7379889266
# Successfully built littleutils
# Installing collected packages: littleutils, outdated, pandas-flavor, pingouin
# Successfully installed littleutils-0.2.2 outdated-0.2.2 pandas-flavor-0.5.0 pingouin-0.5.3

# %%
import pandas as pd

print("Airbnb paises por analizar")
symbol_data_to_load = ['amsterdam_weekdays.csv', 'amsterdam_weekends.csv', 'athens_weekdays.csv', 'athens_weekends.csv', 'barcelona_weekdays.csv', 'barcelona_weekends.csv', 'berlin_weekdays.csv', 'berlin_weekends.csv', 'budapest_weekdays.csv', 'budapest_weekends.csv', 'london_weekdays.csv', 'london_weekends.csv', 'paris_weekdays.csv', 'paris_weekends.csv', 'lisbon_weekdays.csv', 'lisbon_weekends.csv', 'rome_weekdays.csv', 'rome_weekends.csv', 'vienna_weekdays.csv', 'vienna_weekends.csv']
list_of_df = []

print(" --- Inicio de Loop --- ")
for i in symbol_data_to_load:
    print("Procesando Pais: " + i)
    temp_df = pd.read_csv(i, sep=',')
    temp_df['Country'] = i[:-4]
    list_of_df.append(temp_df)


print("Agregando la data")
agg_df = pd.concat(list_of_df, axis=0)

print(agg_df.shape)

print("Head del DataFrame agg_df: ")
agg_df.head()
# Out:
# Airbnb paises por analizar
#  --- Inicio de Loop ---
# Procesando Pais: amsterdam_weekdays.csv
# Procesando Pais: amsterdam_weekends.csv
# Procesando Pais: athens_weekdays.csv
# Procesando Pais: athens_weekends.csv
# Procesando Pais: barcelona_weekdays.csv
# Procesando Pais: barcelona_weekends.csv
# Procesando Pais: berlin_weekdays.csv
# Procesando Pais: berlin_weekends.csv
# Procesando Pais: budapest_weekdays.csv
# Procesando Pais: budapest_weekends.csv
# Procesando Pais: london_weekdays.csv
# Procesando Pais: london_weekends.csv
# Procesando Pais: paris_weekdays.csv
# Procesando Pais: paris_weekends.csv
# Procesando Pais: lisbon_weekdays.csv
# Procesando Pais: lisbon_weekends.csv
# Procesando Pais: rome_weekdays.csv
# Procesando Pais: rome_weekends.csv
# Procesando Pais: vienna_weekdays.csv
# Procesando Pais: vienna_weekends.csv
# Agregando la data
# (51707, 21)
# Head del DataFrame agg_df:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0         1  5.022964    2.539380   78.690379         4.166708   98.253896
# 1         1  0.488389    0.239404  631.176378        33.421209  837.280757
# 2         1  5.748312    3.651621   75.275877         3.985908   95.386955
# 3         2  0.384862    0.439876  493.272534        26.119108  875.033098
# 4         1  0.544738    0.318693  552.830324        29.272733  815.305740
#
#    rest_index_norm      lng       lat             Country
# 0         6.846473  4.90569  52.41772  amsterdam_weekdays
# 1        58.342928  4.90005  52.37432  amsterdam_weekdays
# 2         6.646700  4.97512  52.36103  amsterdam_weekdays
# 3        60.973565  4.89417  52.37663  amsterdam_weekdays
# 4        56.811677  4.90051  52.37508  amsterdam_weekdays
#
# [5 rows x 21 columns]

# %%
dft = agg_df[['Country','realSum', 'guest_satisfaction_overall', 'cleanliness_rating','bedrooms', 'person_capacity']]
dft.head()
# Out:
#               Country     realSum  guest_satisfaction_overall  \
# 0  amsterdam_weekdays  194.033698                        93.0
# 1  amsterdam_weekdays  344.245776                        85.0
# 2  amsterdam_weekdays  264.101422                        87.0
# 3  amsterdam_weekdays  433.529398                        90.0
# 4  amsterdam_weekdays  485.552926                        98.0
#
#    cleanliness_rating  bedrooms  person_capacity
# 0                10.0         1              2.0
# 1                 8.0         1              4.0
# 2                 9.0         1              2.0
# 3                 9.0         2              4.0
# 4                10.0         1              2.0

# %% [markdown]
# # **Descripción de las columnas**
#
# **realSum**	The total price of the Airbnb listing. (Numeric) Precio de referencia (Númerico)
#
# **room_type	** Tipo de cuarto ofrecido (ej privado, compartido) (Categoria)
#
# **room_shared**	Sí el dormitorio es compartido o no (Booleano)
#
# **room_private**	Sí el dormitorio es privado o no (Booleano)
#
# **person_capacity**	Maximo de personas que se hospedan (Numerico)
#
# **host_is_superhost**	Sí el usuario airbnb es "superanfitrio" o no (Booleano)
#
# **multi**	Sí la propiedad posee multiples espacios (Booleano)
#
# **biz**	Sí la propiedad es apta para viaje de negocios (Booleano)
#
# **cleanliness_rating**	Puntuación de calidad de limpieza (Numerico)
#
# **guest_satisfaction_overall**	Puntuación por satisfacción de la persona que se hospeda (Numerico)
#
# **bedrooms**	Cantidad de cuartos que dispone la propiedad (Numerico)
#
# **dist**	Distancia al centro de la ciudad (Numerico)
#
# **metro_dist**	Distancia al estación de metro mas cercana (Numerico)

# %%
data.info()

# %%
sns.boxplot(x='bedrooms', y = 'realSum', data = data)
plt.title("Precio vs Cantidad de Dormitorios")

# %% [markdown]
# # **Analisis de precio vs cantidad de dormitorios**
#
# Se visualiza que la tendencia es alcista en cuestión de precios a medida que la propiedad dispone de mas cuartos, pero la demanda de propiedades demuestra que las propiedades de hasta 4 dormitorios son mas caras que incluso las de hasta 5 dormitorios

# %%
from vega_datasets import data
df = agg_df

factors = ['realSum', 'guest_satisfaction_overall', 'cleanliness_rating',
           'bedrooms', 'person_capacity']
new_max = 100
new_min = 0
new_range = new_max - new_min

factor_stats = {}
for factor in factors:
    factor_stats[factor] = {
        'max_val': df[factor].max(),
        'min_val': df[factor].min(),
        'val_range': df[factor].max() - df[factor].min()
    }
dft.rename(columns={
    'realSum': 'Precio Promedio por Mes',
    'guest_satisfaction_overall': 'Nivel de Satisfacción General',
    'cleanliness_rating': 'Puntuación de Limpieza',
    'bedrooms': 'Cantidad de Dormitorios',
    'person_capacity': 'Capacidad de Huespedes'
}, inplace=True)

dft.head()
# Out:
# <ipython-input-9-1f0f6cb0c715>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dft.rename(columns={
#               Country  Precio Promedio por Mes  Nivel de Satisfacción General  \
# 0  amsterdam_weekdays               194.033698                           93.0
# 1  amsterdam_weekdays               344.245776                           85.0
# 2  amsterdam_weekdays               264.101422                           87.0
# 3  amsterdam_weekdays               433.529398                           90.0
# 4  amsterdam_weekdays               485.552926                           98.0
#
#    Puntuación de Limpieza  Cantidad de Dormitorios  Capacidad de Huespedes
# 0                    10.0                        1                     2.0
# 1                     8.0                        1                     4.0
# 2                     9.0                        1                     2.0
# 3                     9.0                        2                     4.0
# 4                    10.0                        1                     2.0

# %%
import matplotlib.pyplot as plt

capacidad_huespedes = [4, 6, 2, 4]
puntuacion_satisfaccion = [4.2, 4.5, 4.0, 4.3]

plt.figure(figsize=(8, 6))
plt.scatter(capacidad_huespedes, puntuacion_satisfaccion)
plt.xlabel('Capacidad de Huéspedes')
plt.ylabel('Puntuación de Satisfacción')
plt.title('Relación entre Capacidad de Huéspedes y Satisfacción')
plt.show()

# %% [markdown]
# *Lo que se analiza en el grafico es que el nivel de satisfaccion del cliente aumenta en propiedades de mayor capacidad dado que en muchas de estas las comodidades y el lujo es mayor en la relacion costo-beneficio por persona*

# %% [markdown]
# **Motivación y audiencia:**
# Este análisis se centra en las propiedades de Airbnb en las principales ciudades de Europa, con el objetivo de comprender la relación entre el precio, la capacidad de alojamiento y el nivel de satisfacción de los clientes. La motivación detrás de este análisis es proporcionar información valiosa tanto para los propietarios y administradores de propiedades de Airbnb, como para los viajeros interesados en alquilar propiedades en Europa. Los propietarios y administradores podrán tomar decisiones informadas sobre los precios y la capacidad de sus propiedades, mientras que los viajeros podrán tener una idea de qué esperar en términos de calidad y relación precio-capacidad.
#
# **Preguntas e Hipótesis:**
# 1. ¿Existe una relación entre el precio y la capacidad de alojamiento de las propiedades de Airbnb en las principales ciudades de Europa? Se plantea la hipótesis de que las propiedades con mayor capacidad tienden a tener precios más altos.
#
# 2. ¿Existe una relación entre el precio y el nivel de satisfacción de los clientes en Airbnb? Se plantea la hipótesis de que las propiedades con precios más altos tienen una mayor puntuación de satisfacción por parte de los huéspedes.
#
# 3. ¿Existen diferencias significativas en términos de precios, capacidad y nivel de satisfacción entre las diferentes ciudades de Europa? Se plantea la hipótesis de que puede haber variaciones en estas variables entre ciudades.
#
# **Análisis Exploratorio de los datos**:
# Durante el análisis exploratorio de los datos, se llevarán a cabo las siguientes tareas:
#
# 1. Limpieza de datos: Se realizará una limpieza de los datos para eliminar valores faltantes o inconsistentes, y se convertirán los formatos de datos en el formato adecuado para su análisis.
#
# 2. Estadísticas descriptivas: Se calcularán estadísticas descriptivas para obtener una visión general de los datos, como el rango, la media, la mediana y la desviación estándar de los precios, la capacidad y la puntuación de satisfacción.
#
# 3. Visualización de datos: Se crearán gráficos y visualizaciones para examinar la distribución de los precios, la capacidad y la puntuación de satisfacción. Se utilizarán histogramas, diagramas de dispersión y gráficos de barras para visualizar las relaciones entre estas variables.
#
# 4. Análisis de correlación: Se calculará la matriz de correlación para evaluar la relación entre el precio, la capacidad y la puntuación de satisfacción. Se explorarán las correlaciones positivas o negativas entre estas variables.
#
# 5. Comparación entre ciudades: Se compararán los precios, la capacidad y la satisfacción entre diferentes ciudades de Europa mediante gráficos o tablas. Esto permitirá identificar patrones y posibles diferencias significativas entre las ciudades.
#
# *El análisis exploratorio de los datos proporcionará información valiosa sobre las propiedades de Airbnb en las principales ciudades de Europa, permitiendo a los propietarios, administradores y viajeros comprender mejor la relación entre el precio, la capacidad y el nivel de satisfacción.*

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

colores = ['blue', 'green', 'red', 'orange', 'purple']

plt.figure(figsize=(10, 6))
plt.bar(agg_df['Country'], agg_df['realSum'], color=colores)
plt.xlabel('País')
plt.ylabel('Precio Promedio por Mes')
plt.title('Precio Promedio por Mes en cada País')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# En base a las consigna de la entrega determine que utilizare las siguiente perspectivas de analisis
#
# En el caso de Metodo de Feature Selection a fines de reducir las dimensiones del dataset utilizare un algoritmo de Recursive Feature Elimination para eliminar las carecteristicas menos relevantes de la base de datos.
#
# En el del algoritmo de regresión, optare por un modelo de Regresion Lineal para encontrar mas rapido y reducir los valores de los precios a fin de tener con mayor exactitud los mejores precios vs las valoraciones de satisfaccion del cliente.
# Usando tambien un modelo Regresion de albol de bosque para dividir las características en paises del dataset del Aibnbnb y realiza una predicción basada en la región a la que pertenece una instancia.
#
# En el caso de la clasificacion optare por un algoritmo de Bosque Aleatorio para que trabaje en paralelo y realizar una calificacion promediando las predicciones de cada archivo del dataset y realizar una comparativa general de los archivos individuales.
#
# Metricas para validar el modelo:
#
# Recall: Lo utilizare para medir la proporción de instancias positivas clasificadas correctamente respecto al total de instancias positivas.
# Error absoluto medio (MAE): Para calcular el promedio de las diferencias absolutas entre las predicciones y los valores reales.
#
# Conclusion a las que quiero llegar:
#
# Al analizar las métricas obtenidas y compararlas con las expectativas iniciales establecidas para el proyecto de Airbnb y el dataset de propiedades en Europa, podemos evaluar el rendimiento y la precisión de los modelos de regresión y clasificación implementados. Esta evaluación nos permitirá determinar si los modelos cumplen con los objetivos establecidos, especialmente en términos de predecir con precisión los precios y clasificaciones de las propiedades.
#
# Además, al identificar las características más importantes seleccionadas a través del proceso de "Feature Selection" y examinar su relación con las predicciones generadas por los modelos, para obtener una comprensión más profunda de las variables que tienen un impacto significativo en los resultados obtenidos.

# %%
dataset= agg_df

# %%
print(dataset.columns)
# Out:
# Index(['Unnamed: 0', 'realSum', 'room_type', 'room_shared', 'room_private',
#        'person_capacity', 'host_is_superhost', 'multi', 'biz',
#        'cleanliness_rating', 'guest_satisfaction_overall', 'bedrooms', 'dist',
#        'metro_dist', 'attr_index', 'attr_index_norm', 'rest_index',
#        'rest_index_norm', 'lng', 'lat', 'Country'],
#       dtype='object')

# %%
  import numpy as np
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, mean_absolute_error
from sklearn.preprocessing import OneHotEncoder

dataset = agg_df

print("Resultados de los modelos aplicados")

X = dataset.drop(['realSum', 'guest_satisfaction_overall'], axis=1)
y_precio = dataset['realSum']
y_valoracion = dataset['guest_satisfaction_overall']

categorical_columns = ['room_type', 'Country']
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
X_encoded = pd.DataFrame(encoder.fit_transform(X[categorical_columns]))
X_encoded.columns = [f"{col}_{category}" for col, categories in zip(categorical_columns, encoder.categories_) for category in categories]
X_encoded.index = X.index
X = pd.concat([X.drop(categorical_columns, axis=1), X_encoded], axis=1)

estimador_regresion = LinearRegression()
rfe_regresion = RFE(estimator=estimador_regresion, n_features_to_select=5)
X_regresion = rfe_regresion.fit_transform(X, y_precio)

estimador_clasificacion = RandomForestClassifier()
rfe_clasificacion = RFE(estimator=estimador_clasificacion, n_features_to_select=5)
X_clasificacion = rfe_clasificacion.fit_transform(X, y_valoracion)


modelo_regresion = LinearRegression()
modelo_regresion.fit(X_regresion, y_precio)


modelo_clasificacion = RandomForestClassifier()
modelo_clasificacion.fit(X_clasificacion, y_valoracion)


predicciones_regresion = modelo_regresion.predict(X_regresion)
predicciones_clasificacion = modelo_clasificacion.predict(X_clasificacion)

accuracy = accuracy_score(y_valoracion, predicciones_clasificacion)
mae = mean_absolute_error(y_precio, predicciones_regresion)

print("Métricas de validación:")
print("Accuracy:", accuracy)
print("MAE:", mae)

caracteristicas_regresion = X.columns[rfe_regresion.support_]
caracteristicas_clasificacion = X.columns[rfe_clasificacion.support_]

print("Características seleccionadas para regresión:")
print(caracteristicas_regresion)

print("Características seleccionadas para clasificación:")
print(caracteristicas_clasificacion)
# Out:
# Resultados de los modelos aplicados
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Métricas de validación:
# Accuracy: 0.9999613205175315
# MAE: 130.52879474671533
# Características seleccionadas para regresión:
# Index(['Country_amsterdam_weekdays', 'Country_amsterdam_weekends',
#        'Country_london_weekends', 'Country_paris_weekdays',
#        'Country_paris_weekends'],
#       dtype='object')
# Características seleccionadas para clasificación:
# Index(['dist', 'metro_dist', 'attr_index', 'rest_index', 'lng'], dtype='object')

# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
df = pd.read_csv

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/AirbnbEurope'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/AirbnbEurope

# %% [markdown]
# # Entrega TP Coderhouse 19/06/2023
#
# Limpieza de datos

# %%
import pandas as pd


archivos = ['amsterdam_weekdays.csv', 'amsterdam_weekends.csv', 'athens_weekdays.csv', 'athens_weekends.csv', 'barcelona_weekdays.csv', 'barcelona_weekends.csv', 'berlin_weekdays.csv', 'berlin_weekends.csv', 'budapest_weekdays.csv', 'budapest_weekends.csv', 'london_weekdays.csv', 'london_weekends.csv', 'paris_weekdays.csv', 'paris_weekends.csv', 'lisbon_weekdays.csv', 'lisbon_weekends.csv', 'rome_weekdays.csv', 'rome_weekends.csv', 'vienna_weekdays.csv', 'vienna_weekends.csv']
dataframes = []
headers = ['realSum','room_type','room_shared','room_private','person_capacity','host_is_superhost','multi biz cleanliness_rating','guest_satisfaction_overall', 'bedrooms dist', 'metro_dist' ,'attr_index', 'attr_index_norm' , 'rest_index', 'rest_index_norm']  # Reemplaza con tus cabeceras

for archivo in archivos:
    df = pd.read_csv(archivo, names=headers)
    dataframes.append(df)

for df in dataframes:

    print(df.head())
    print()
# Out:
#                                                                                            realSum  \
# NaN    realSum            room_type    room_shared room_private person_capacity  host_is_superhost
# 0.0    194.03369812293488 Private room False       True         2.0                          False
# 1.0    344.2457760176224  Private room False       True         4.0                          False
# 2.0    264.1014224451058  Private room False       True         2.0                          False
# 3.0    433.5293979799874  Private room False       True         4.0                          False
#
#                                                                                 room_type  \
# NaN    realSum            room_type    room_shared room_private person_capacity     multi
# 0.0    194.03369812293488 Private room False       True         2.0                     1
# 1.0    344.2457760176224  Private room False       True         4.0                     0
# 2.0    264.1014224451058  Private room False       True         2.0                     0
# 3.0    433.5293979799874  Private room False       True         4.0                     0
#
#                                                                                 room_shared  \
# NaN    realSum            room_type    room_shared room_private person_capacity         biz
# 0.0    194.03369812293488 Private room False       True         2.0                       0
# 1.0    344.2457760176224  Private room False       True         4.0                       0
# 2.0    264.1014224451058  Private room False       True         2.0                       1
# 3.0    433.5293979799874  Private room False       True         4.0                       1
#
#                                                                                        room_private  \
# NaN    realSum            room_type    room_shared room_private person_capacity  cleanliness_rating
# 0.0    194.03369812293488 Private room False       True         2.0                            10.0
# 1.0    344.2457760176224  Private room False       True         4.0                             8.0
# 2.0    264.1014224451058  Private room False       True         2.0                             9.0
# 3.0    433.5293979799874  Private room False       True         4.0                             9.0
#
#                                                                                             person_capacity  \
# NaN    realSum            room_type    room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0    194.03369812293488 Private room False       True         2.0                                    93.0
# 1.0    344.2457760176224  Private room False       True         4.0                                    85.0
# 2.0    264.1014224451058  Private room False       True         2.0                                    87.0
# 3.0    433.5293979799874  Private room False       True         4.0                                    90.0
#
#                                                                                 host_is_superhost  \
# NaN    realSum            room_type    room_shared room_private person_capacity          bedrooms
# 0.0    194.03369812293488 Private room False       True         2.0                             1
# 1.0    344.2457760176224  Private room False       True         4.0                             1
# 2.0    264.1014224451058  Private room False       True         2.0                             1
# 3.0    433.5293979799874  Private room False       True         4.0                             2
#
#                                                                                 multi biz cleanliness_rating  \
# NaN    realSum            room_type    room_shared room_private person_capacity                         dist
# 0.0    194.03369812293488 Private room False       True         2.0                        5.022963798088291
# 1.0    344.2457760176224  Private room False       True         4.0                       0.4883892888289836
# 2.0    264.1014224451058  Private room False       True         2.0                        5.748311915159562
# 3.0    433.5293979799874  Private room False       True         4.0                      0.38486201282160204
#
#                                                                                 guest_satisfaction_overall  \
# NaN    realSum            room_type    room_shared room_private person_capacity                 metro_dist
# 0.0    194.03369812293488 Private room False       True         2.0                      2.539380002594493
# 1.0    344.2457760176224  Private room False       True         4.0                    0.23940392283498632
# 2.0    264.1014224451058  Private room False       True         2.0                     3.6516212887936557
# 3.0    433.5293979799874  Private room False       True         4.0                     0.4398760761319157
#
#                                                                                       bedrooms dist  \
# NaN    realSum            room_type    room_shared room_private person_capacity          attr_index
# 0.0    194.03369812293488 Private room False       True         2.0               78.69037927190317
# 1.0    344.2457760176224  Private room False       True         4.0               631.1763782503964
# 2.0    264.1014224451058  Private room False       True         2.0               75.27587691428164
# 3.0    433.5293979799874  Private room False       True         4.0              493.27253443070873
#
#                                                                                          metro_dist  \
# NaN    realSum            room_type    room_shared room_private person_capacity     attr_index_norm
# 0.0    194.03369812293488 Private room False       True         2.0               4.166707868490748
# 1.0    344.2457760176224  Private room False       True         4.0              33.421208615275404
# 2.0    264.1014224451058  Private room False       True         2.0              3.9859076998790086
# 3.0    433.5293979799874  Private room False       True         4.0               26.11910845442667
#
#                                                                                         attr_index  \
# NaN    realSum            room_type    room_shared room_private person_capacity         rest_index
# 0.0    194.03369812293488 Private room False       True         2.0              98.25389587009934
# 1.0    344.2457760176224  Private room False       True         4.0              837.2807567422693
# 2.0    264.1014224451058  Private room False       True         2.0               95.3869549262145
# 3.0    433.5293979799874  Private room False       True         4.0              875.0330975776227
#
#                                                                                    attr_index_norm  \
# NaN    realSum            room_type    room_shared room_private person_capacity    rest_index_norm
# 0.0    194.03369812293488 Private room False       True         2.0              6.846472824200016
# 1.0    344.2457760176224  Private room False       True         4.0              58.34292774344904
# 2.0    264.1014224451058  Private room False       True         2.0              6.646700254501156
# 3.0    433.5293979799874  Private room False       True         4.0              60.97356516795285
#
#                                                                                          rest_index  \
# NaN    realSum            room_type    room_shared room_private person_capacity                 lng
# 0.0    194.03369812293488 Private room False       True         2.0                         4.90569
# 1.0    344.2457760176224  Private room False       True         4.0                         4.90005
# 2.0    264.1014224451058  Private room False       True         2.0              4.9751199999999995
# 3.0    433.5293979799874  Private room False       True         4.0                         4.89417
#
#                                                                                     rest_index_norm
# NaN    realSum            room_type    room_shared room_private person_capacity                 lat
# 0.0    194.03369812293488 Private room False       True         2.0                        52.41772
# 1.0    344.2457760176224  Private room False       True         4.0              52.374320000000004
# 2.0    264.1014224451058  Private room False       True         2.0                        52.36103
# 3.0    433.5293979799874  Private room False       True         4.0                        52.37663
#
#                                                                                           realSum  \
# NaN   realSum            room_type    room_shared room_private person_capacity  host_is_superhost
# 0.0   319.6400534295691  Private room False       True         2.0                          False
# 1.0   347.9952194596115  Private room False       True         2.0                          False
# 2.0   482.97518337121835 Private room False       True         4.0                          False
# 3.0   485.5529257375859  Private room False       True         2.0                           True
#
#                                                                                room_type  \
# NaN   realSum            room_type    room_shared room_private person_capacity     multi
# 0.0   319.6400534295691  Private room False       True         2.0                     0
# 1.0   347.9952194596115  Private room False       True         2.0                     0
# 2.0   482.97518337121835 Private room False       True         4.0                     0
# 3.0   485.5529257375859  Private room False       True         2.0                     0
#
#                                                                                room_shared  \
# NaN   realSum            room_type    room_shared room_private person_capacity         biz
# 0.0   319.6400534295691  Private room False       True         2.0                       1
# 1.0   347.9952194596115  Private room False       True         2.0                       1
# 2.0   482.97518337121835 Private room False       True         4.0                       1
# 3.0   485.5529257375859  Private room False       True         2.0                       0
#
#                                                                                       room_private  \
# NaN   realSum            room_type    room_shared room_private person_capacity  cleanliness_rating
# 0.0   319.6400534295691  Private room False       True         2.0                             9.0
# 1.0   347.9952194596115  Private room False       True         2.0                             9.0
# 2.0   482.97518337121835 Private room False       True         4.0                             9.0
# 3.0   485.5529257375859  Private room False       True         2.0                            10.0
#
#                                                                                            person_capacity  \
# NaN   realSum            room_type    room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0   319.6400534295691  Private room False       True         2.0                                    88.0
# 1.0   347.9952194596115  Private room False       True         2.0                                    87.0
# 2.0   482.97518337121835 Private room False       True         4.0                                    90.0
# 3.0   485.5529257375859  Private room False       True         2.0                                    98.0
#
#                                                                                host_is_superhost  \
# NaN   realSum            room_type    room_shared room_private person_capacity          bedrooms
# 0.0   319.6400534295691  Private room False       True         2.0                             1
# 1.0   347.9952194596115  Private room False       True         2.0                             1
# 2.0   482.97518337121835 Private room False       True         4.0                             2
# 3.0   485.5529257375859  Private room False       True         2.0                             1
#
#                                                                                multi biz cleanliness_rating  \
# NaN   realSum            room_type    room_shared room_private person_capacity                         dist
# 0.0   319.6400534295691  Private room False       True         2.0                         4.76335974080673
# 1.0   347.9952194596115  Private room False       True         2.0                        5.748310293271628
# 2.0   482.97518337121835 Private room False       True         4.0                      0.38487208614316554
# 3.0   485.5529257375859  Private room False       True         2.0                       0.5447225587213453
#
#                                                                                guest_satisfaction_overall  \
# NaN   realSum            room_type    room_shared room_private person_capacity                 metro_dist
# 0.0   319.6400534295691  Private room False       True         2.0                     0.8521173969261567
# 1.0   347.9952194596115  Private room False       True         2.0                     3.6515914990858325
# 2.0   482.97518337121835 Private room False       True         4.0                    0.43985163027299534
# 3.0   485.5529257375859  Private room False       True         2.0                     0.3186881484356986
#
#                                                                                      bedrooms dist  \
# NaN   realSum            room_type    room_shared room_private person_capacity          attr_index
# 0.0   319.6400534295691  Private room False       True         2.0              110.90612328634465
# 1.0   347.9952194596115  Private room False       True         2.0               75.27593655810635
# 2.0   482.97518337121835 Private room False       True         4.0               493.2725174909284
# 3.0   485.5529257375859  Private room False       True         2.0                552.849513615576
#
#                                                                                         metro_dist  \
# NaN   realSum            room_type    room_shared room_private person_capacity     attr_index_norm
# 0.0   319.6400534295691  Private room False       True         2.0                5.87197140434776
# 1.0   347.9952194596115  Private room False       True         2.0               3.985516162741217
# 2.0   482.97518337121835 Private room False       True         4.0              26.116521175111636
# 3.0   485.5529257375859  Private room False       True         2.0              29.270850325159042
#
#                                                                                        attr_index  \
# NaN   realSum            room_type    room_shared room_private person_capacity         rest_index
# 0.0   319.6400534295691  Private room False       True         2.0               136.982207779159
# 1.0   347.9952194596115  Private room False       True         2.0              95.38646779321537
# 2.0   482.97518337121835 Private room False       True         4.0              875.1148174970866
# 3.0   485.5529257375859  Private room False       True         2.0               815.303994178939
#
#                                                                                    attr_index_norm  \
# NaN   realSum            room_type    room_shared room_private person_capacity     rest_index_norm
# 0.0   319.6400534295691  Private room False       True         2.0              11.941560304263303
# 1.0   347.9952194596115  Private room False       True         2.0               8.315410269921582
# 2.0   482.97518337121835 Private room False       True         4.0               76.28900523448691
# 3.0   485.5529257375859  Private room False       True         2.0               71.07493718082569
#
#                                                                                         rest_index  \
# NaN   realSum            room_type    room_shared room_private person_capacity                 lng
# 0.0   319.6400534295691  Private room False       True         2.0                         4.84639
# 1.0   347.9952194596115  Private room False       True         2.0              4.9751199999999995
# 2.0   482.97518337121835 Private room False       True         4.0                         4.89417
# 3.0   485.5529257375859  Private room False       True         2.0                         4.90051
#
#                                                                                rest_index_norm
# NaN   realSum            room_type    room_shared room_private person_capacity             lat
# 0.0   319.6400534295691  Private room False       True         2.0                    52.34137
# 1.0   347.9952194596115  Private room False       True         2.0                    52.36103
# 2.0   482.97518337121835 Private room False       True         4.0                    52.37663
# 3.0   485.5529257375859  Private room False       True         2.0                    52.37508
#
#                                                                                               realSum  \
# NaN    realSum            room_type       room_shared room_private person_capacity  host_is_superhost
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                          False
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                           True
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                           True
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                           True
#
#                                                                                    room_type  \
# NaN    realSum            room_type       room_shared room_private person_capacity     multi
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                     0
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                     1
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                     0
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                     1
#
#                                                                                    room_shared  \
# NaN    realSum            room_type       room_shared room_private person_capacity         biz
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                       0
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                       0
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                       1
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                       0
#
#                                                                                           room_private  \
# NaN    realSum            room_type       room_shared room_private person_capacity  cleanliness_rating
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                            10.0
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                            10.0
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                            10.0
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                            10.0
#
#                                                                                                person_capacity  \
# NaN    realSum            room_type       room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                                   100.0
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                                    96.0
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                                    98.0
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                                    99.0
#
#                                                                                    host_is_superhost  \
# NaN    realSum            room_type       room_shared room_private person_capacity          bedrooms
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                             2
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                             1
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                             1
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                             1
#
#                                                                                    multi biz cleanliness_rating  \
# NaN    realSum            room_type       room_shared room_private person_capacity                         dist
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                        2.813963501242435
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                      0.40729291966323267
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                       1.2372111314777294
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                        4.367457161013417
#
#                                                                                    guest_satisfaction_overall  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 metro_dist
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                     0.8818900015142561
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                    0.30456786842403555
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                    0.28848805731090266
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                     0.2974673006070027
#
#                                                                                          bedrooms dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity          attr_index
# 0.0    129.82447917887188 Entire home/apt False       False        4.0               55.34857178007335
# 1.0    138.9637475687203  Entire home/apt False       False        4.0              240.30665389568526
# 2.0    156.30492348791978 Entire home/apt False       False        3.0              199.50736576152912
# 3.0    91.62702411360814  Entire home/apt False       False        4.0              39.803047454722574
#
#                                                                                             metro_dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity     attr_index_norm
# 0.0    129.82447917887188 Entire home/apt False       False        4.0               2.086871150558837
# 1.0    138.9637475687203  Entire home/apt False       False        4.0                9.06055941777308
# 2.0    156.30492348791978 Entire home/apt False       False        3.0               7.522256718494376
# 3.0    91.62702411360814  Entire home/apt False       False        4.0              1.5007402859036303
#
#                                                                                             attr_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity          rest_index
# 0.0    129.82447917887188 Entire home/apt False       False        4.0               78.77837697233369
# 1.0    138.9637475687203  Entire home/apt False       False        4.0               407.1676962193295
# 2.0    156.30492348791978 Entire home/apt False       False        3.0              395.96740259345165
# 3.0    91.62702411360814  Entire home/apt False       False        4.0               58.70657846129648
#
#                                                                                        attr_index_norm  \
# NaN    realSum            room_type       room_shared room_private person_capacity     rest_index_norm
# 0.0    129.82447917887188 Entire home/apt False       False        4.0               5.915159963046886
# 1.0    138.9637475687203  Entire home/apt False       False        4.0               30.57262852430238
# 2.0    156.30492348791978 Entire home/apt False       False        3.0              29.731642317472694
# 3.0    91.62702411360814  Entire home/apt False       False        4.0               4.408047180302864
#
#                                                                                             rest_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 lng
# 0.0    129.82447917887188 Entire home/apt False       False        4.0                          23.766
# 1.0    138.9637475687203  Entire home/apt False       False        4.0              23.731679999999997
# 2.0    156.30492348791978 Entire home/apt False       False        3.0              23.721999999999998
# 3.0    91.62702411360814  Entire home/apt False       False        4.0              23.727120000000003
#
#                                                                                        rest_index_norm
# NaN    realSum            room_type       room_shared room_private person_capacity                 lat
# 0.0    129.82447917887188 Entire home/apt False       False        4.0              37.983000000000004
# 1.0    138.9637475687203  Entire home/apt False       False        4.0              37.977759999999996
# 2.0    156.30492348791978 Entire home/apt False       False        3.0                          37.979
# 3.0    91.62702411360814  Entire home/apt False       False        4.0                        38.01435
#
#                                                                                               realSum  \
# NaN    realSum            room_type       room_shared room_private person_capacity  host_is_superhost
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                           True
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                           True
# 2.0    76.62925034565183  Private room    False       True         2.0                          False
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                           True
#
#                                                                                    room_type  \
# NaN    realSum            room_type       room_shared room_private person_capacity     multi
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                     1
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                     1
# 2.0    76.62925034565183  Private room    False       True         2.0                     0
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                     0
#
#                                                                                    room_shared  \
# NaN    realSum            room_type       room_shared room_private person_capacity         biz
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                       0
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                       0
# 2.0    76.62925034565183  Private room    False       True         2.0                       0
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                       1
#
#                                                                                           room_private  \
# NaN    realSum            room_type       room_shared room_private person_capacity  cleanliness_rating
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                            10.0
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                            10.0
# 2.0    76.62925034565183  Private room    False       True         2.0                            10.0
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                            10.0
#
#                                                                                                person_capacity  \
# NaN    realSum            room_type       room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                                    96.0
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                                    99.0
# 2.0    76.62925034565183  Private room    False       True         2.0                                   100.0
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                                   100.0
#
#                                                                                    host_is_superhost  \
# NaN    realSum            room_type       room_shared room_private person_capacity          bedrooms
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                             1
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                             1
# 2.0    76.62925034565183  Private room    False       True         2.0                             1
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                             2
#
#                                                                                    multi biz cleanliness_rating  \
# NaN    realSum            room_type       room_shared room_private person_capacity                         dist
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                       0.4072776803415383
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                          4.3674630947653
# 2.0    76.62925034565183  Private room    False       True         2.0                       2.1941737592842085
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                       2.5089816011625437
#
#                                                                                    guest_satisfaction_overall  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 metro_dist
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                    0.30456967903143106
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                     0.2974735335258959
# 2.0    76.62925034565183  Private room    False       True         2.0                    0.38524747960864786
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                     0.5634734972779578
#
#                                                                                          bedrooms dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity          attr_index
# 0.0    138.9637475687203  Entire home/apt False       False        4.0              240.30649638138368
# 1.0    91.62702411360814  Entire home/apt False       False        4.0               39.80299633186126
# 2.0    76.62925034565183  Private room    False       True         2.0               78.73400136046092
# 3.0    151.85245940055773 Entire home/apt False       False        4.0               68.77488123715358
#
#                                                                                             metro_dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity     attr_index_norm
# 0.0    138.9637475687203  Entire home/apt False       False        4.0                9.05420531809665
# 1.0    91.62702411360814  Entire home/apt False       False        4.0              1.4996868852524219
# 2.0    76.62925034565183  Private room    False       True         2.0               2.966519110251319
# 3.0    151.85245940055773 Entire home/apt False       False        4.0               2.591281987069666
#
#                                                                                             attr_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity          rest_index
# 0.0    138.9637475687203  Entire home/apt False       False        4.0              407.16795762249257
# 1.0    91.62702411360814  Entire home/apt False       False        4.0               58.70652227440233
# 2.0    76.62925034565183  Private room    False       True         2.0              113.32668422403269
# 3.0    151.85245940055773 Entire home/apt False       False        4.0              101.16206903003817
#
#                                                                                        attr_index_norm  \
# NaN    realSum            room_type       room_shared room_private person_capacity     rest_index_norm
# 0.0    138.9637475687203  Entire home/apt False       False        4.0               6.080621638018715
# 1.0    91.62702411360814  Entire home/apt False       False        4.0              0.8767196508265679
# 2.0    76.62925034565183  Private room    False       True         2.0              1.6924138438626009
# 3.0    151.85245940055773 Entire home/apt False       False        4.0              1.5107482167374076
#
#                                                                                             rest_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 lng
# 0.0    138.9637475687203  Entire home/apt False       False        4.0              23.731679999999997
# 1.0    91.62702411360814  Entire home/apt False       False        4.0              23.727120000000003
# 2.0    76.62925034565183  Private room    False       True         2.0                        23.73391
# 3.0    151.85245940055773 Entire home/apt False       False        4.0                          23.732
#
#                                                                                        rest_index_norm
# NaN    realSum            room_type       room_shared room_private person_capacity                 lat
# 0.0    138.9637475687203  Entire home/apt False       False        4.0              37.977759999999996
# 1.0    91.62702411360814  Entire home/apt False       False        4.0                        38.01435
# 2.0    76.62925034565183  Private room    False       True         2.0              37.995290000000004
# 3.0    151.85245940055773 Entire home/apt False       False        4.0              37.998000000000005
#
#                                                                                               realSum  \
# NaN    realSum            room_type       room_shared room_private person_capacity  host_is_superhost
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                          False
# 1.0    169.89782856610887 Private room    False       True         2.0                           True
# 2.0    161.98477901645447 Private room    False       True         4.0                          False
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                          False
#
#                                                                                    room_type  \
# NaN    realSum            room_type       room_shared room_private person_capacity     multi
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                     0
# 1.0    169.89782856610887 Private room    False       True         2.0                     1
# 2.0    161.98477901645447 Private room    False       True         4.0                     0
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                     0
#
#                                                                                    room_shared  \
# NaN    realSum            room_type       room_shared room_private person_capacity         biz
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                       1
# 1.0    169.89782856610887 Private room    False       True         2.0                       0
# 2.0    161.98477901645447 Private room    False       True         4.0                       1
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                       1
#
#                                                                                           room_private  \
# NaN    realSum            room_type       room_shared room_private person_capacity  cleanliness_rating
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                            10.0
# 1.0    169.89782856610887 Private room    False       True         2.0                            10.0
# 2.0    161.98477901645447 Private room    False       True         4.0                             9.0
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                            10.0
#
#                                                                                                person_capacity  \
# NaN    realSum            room_type       room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                                    91.0
# 1.0    169.89782856610887 Private room    False       True         2.0                                    88.0
# 2.0    161.98477901645447 Private room    False       True         4.0                                    88.0
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                                    91.0
#
#                                                                                    host_is_superhost  \
# NaN    realSum            room_type       room_shared room_private person_capacity          bedrooms
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                             1
# 1.0    169.89782856610887 Private room    False       True         2.0                             1
# 2.0    161.98477901645447 Private room    False       True         4.0                             1
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                             1
#
#                                                                                    multi biz cleanliness_rating  \
# NaN    realSum            room_type       room_shared room_private person_capacity                         dist
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                        1.111996477976483
# 1.0    169.89782856610887 Private room    False       True         2.0                        1.751839016015303
# 2.0    161.98477901645447 Private room    False       True         4.0                       1.6704928969848183
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                       1.4758465180822207
#
#                                                                                    guest_satisfaction_overall  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 metro_dist
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                     0.6304909460189917
# 1.0    169.89782856610887 Private room    False       True         2.0                    0.12401717176446693
# 2.0    161.98477901645447 Private room    False       True         4.0                    0.08032197629455128
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                    0.09310686464817329
#
#                                                                                          bedrooms dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity          attr_index
# 0.0    474.3174994763423  Entire home/apt False       False        4.0               526.4694202447247
# 1.0    169.89782856610887 Private room    False       True         2.0              320.12752551210633
# 2.0    161.98477901645447 Private room    False       True         4.0              344.07393595254723
# 3.0    367.9568040589289  Entire home/apt False       False        3.0               400.0574494539389
#
#                                                                                             metro_dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity     attr_index_norm
# 0.0    474.3174994763423  Entire home/apt False       False        4.0              17.942926962147965
# 1.0    169.89782856610887 Private room    False       True         2.0              10.910462389566375
# 2.0    161.98477901645447 Private room    False       True         4.0               11.72659467952677
# 3.0    367.9568040589289  Entire home/apt False       False        3.0               13.63460311308965
#
#                                                                                            attr_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity         rest_index
# 0.0    474.3174994763423  Entire home/apt False       False        4.0              915.5870827687069
# 1.0    169.89782856610887 Private room    False       True         2.0              794.2773503129439
# 2.0    161.98477901645447 Private room    False       True         4.0              840.6736172628903
# 3.0    367.9568040589289  Entire home/apt False       False        3.0              946.5898839190221
#
#                                                                                        attr_index_norm  \
# NaN    realSum            room_type       room_shared room_private person_capacity     rest_index_norm
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                20.1548895790265
# 1.0    169.89782856610887 Private room    False       True         2.0               17.48448901470924
# 2.0    161.98477901645447 Private room    False       True         4.0               18.50581364330432
# 3.0    367.9568040589289  Entire home/apt False       False        3.0              20.837356649155502
#
#                                                                                    rest_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity        lng
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                2.17556
# 1.0    169.89782856610887 Private room    False       True         2.0                2.14906
# 2.0    161.98477901645447 Private room    False       True         4.0                2.15357
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                2.16839
#
#                                                                                    rest_index_norm
# NaN    realSum            room_type       room_shared room_private person_capacity             lat
# 0.0    474.3174994763423  Entire home/apt False       False        4.0                    41.39624
# 1.0    169.89782856610887 Private room    False       True         2.0                    41.38714
# 2.0    161.98477901645447 Private room    False       True         4.0                    41.37859
# 3.0    367.9568040589289  Entire home/apt False       False        3.0                     41.3739
#
#                                                                                               realSum  \
# NaN    realSum            room_type       room_shared room_private person_capacity  host_is_superhost
# 0.0    532.0362138385271  Entire home/apt False       False        4.0                          False
# 1.0    169.89782856610887 Private room    False       True         2.0                           True
# 2.0    196.89529173551793 Private room    False       True         2.0                          False
# 3.0    141.27120813647682 Private room    False       True         3.0                          False
#
#                                                                                    room_type  \
# NaN    realSum            room_type       room_shared room_private person_capacity     multi
# 0.0    532.0362138385271  Entire home/apt False       False        4.0                     0
# 1.0    169.89782856610887 Private room    False       True         2.0                     1
# 2.0    196.89529173551793 Private room    False       True         2.0                     1
# 3.0    141.27120813647682 Private room    False       True         3.0                     0
#
#                                                                                    room_shared  \
# NaN    realSum            room_type       room_shared room_private person_capacity         biz
# 0.0    532.0362138385271  Entire home/apt False       False        4.0                       1
# 1.0    169.89782856610887 Private room    False       True         2.0                       0
# 2.0    196.89529173551793 Private room    False       True         2.0                       0
# 3.0    141.27120813647682 Private room    False       True         3.0                       1
#
#                                                                                           room_private  \
# NaN    realSum            room_type       room_shared room_private person_capacity  cleanliness_rating
# 0.0    532.0362138385271  Entire home/apt False       False        4.0                            10.0
# 1.0    169.89782856610887 Private room    False       True         2.0                            10.0
# 2.0    196.89529173551793 Private room    False       True         2.0                             9.0
# 3.0    141.27120813647682 Private room    False       True         3.0                             9.0
#
#                                                                                                person_capacity  \
# NaN    realSum            room_type       room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0    532.0362138385271  Entire home/apt False       False        4.0                                    91.0
# 1.0    169.89782856610887 Private room    False       True         2.0                                    88.0
# 2.0    196.89529173551793 Private room    False       True         2.0                                    90.0
# 3.0    141.27120813647682 Private room    False       True         3.0                                    86.0
#
#                                                                                    host_is_superhost  \
# NaN    realSum            room_type       room_shared room_private person_capacity          bedrooms
# 0.0    532.0362138385271  Entire home/apt False       False        4.0                             1
# 1.0    169.89782856610887 Private room    False       True         2.0                             1
# 2.0    196.89529173551793 Private room    False       True         2.0                             1
# 3.0    141.27120813647682 Private room    False       True         3.0                             1
#
#                                                                                    multi biz cleanliness_rating  \
# NaN    realSum            room_type       room_shared room_private person_capacity                         dist
# ...
#
#                                                                                           room_private  \
# NaN    realSum            room_type       room_shared room_private person_capacity  cleanliness_rating
# 0.0    250.5668139214174  Entire home/apt False       False        3.0                            10.0
# 1.0    156.60425870088588 Entire home/apt False       False        3.0                            10.0
# 2.0    283.0563541593624  Entire home/apt False       False        5.0                            10.0
# 3.0    301.75537012364725 Entire home/apt False       False        4.0                            10.0
#
#                                                                                                person_capacity  \
# NaN    realSum            room_type       room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0    250.5668139214174  Entire home/apt False       False        3.0                                    99.0
# 1.0    156.60425870088588 Entire home/apt False       False        3.0                                    97.0
# 2.0    283.0563541593624  Entire home/apt False       False        5.0                                    95.0
# 3.0    301.75537012364725 Entire home/apt False       False        4.0                                    94.0
#
#                                                                                    host_is_superhost  \
# NaN    realSum            room_type       room_shared room_private person_capacity          bedrooms
# 0.0    250.5668139214174  Entire home/apt False       False        3.0                             1
# 1.0    156.60425870088588 Entire home/apt False       False        3.0                             1
# 2.0    283.0563541593624  Entire home/apt False       False        5.0                             2
# 3.0    301.75537012364725 Entire home/apt False       False        4.0                             2
#
#                                                                                    multi biz cleanliness_rating  \
# NaN    realSum            room_type       room_shared room_private person_capacity                         dist
# 0.0    250.5668139214174  Entire home/apt False       False        3.0                        1.732893381017552
# 1.0    156.60425870088588 Entire home/apt False       False        3.0                        4.807911759774244
# 2.0    283.0563541593624  Entire home/apt False       False        5.0                       2.8117726717374003
# 3.0    301.75537012364725 Entire home/apt False       False        4.0                       3.2405949044170126
#
#                                                                                    guest_satisfaction_overall  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 metro_dist
# 0.0    250.5668139214174  Entire home/apt False       False        3.0                    0.21262706302738918
# 1.0    156.60425870088588 Entire home/apt False       False        3.0                    0.22825310347967212
# 2.0    283.0563541593624  Entire home/apt False       False        5.0                    0.24416286674650642
# 3.0    301.75537012364725 Entire home/apt False       False        4.0                     0.6104299085746427
#
#                                                                                          bedrooms dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity          attr_index
# 0.0    250.5668139214174  Entire home/apt False       False        3.0              118.64683124356394
# 1.0    156.60425870088588 Entire home/apt False       False        3.0               80.14501548622435
# 2.0    283.0563541593624  Entire home/apt False       False        5.0              101.24811200673267
# 3.0    301.75537012364725 Entire home/apt False       False        4.0               92.47393763063063
#
#                                                                                            metro_dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity    attr_index_norm
# 0.0    250.5668139214174  Entire home/apt False       False        3.0              8.496978848776331
# 1.0    156.60425870088588 Entire home/apt False       False        3.0              5.739643396150461
# 2.0    283.0563541593624  Entire home/apt False       False        5.0              7.250956955046468
# 3.0    301.75537012364725 Entire home/apt False       False        4.0               6.62258809506262
#
#                                                                                             attr_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity          rest_index
# 0.0    250.5668139214174  Entire home/apt False       False        3.0              185.09671950723867
# 1.0    156.60425870088588 Entire home/apt False       False        3.0               85.72760015762569
# 2.0    283.0563541593624  Entire home/apt False       False        5.0               151.3642875909518
# 3.0    301.75537012364725 Entire home/apt False       False        4.0              129.86383095833605
#
#                                                                                        attr_index_norm  \
# NaN    realSum            room_type       room_shared room_private person_capacity     rest_index_norm
# 0.0    250.5668139214174  Entire home/apt False       False        3.0               4.424871135625918
# 1.0    156.60425870088588 Entire home/apt False       False        3.0               2.049380369753787
# 2.0    283.0563541593624  Entire home/apt False       False        5.0               3.618472920043242
# 3.0    301.75537012364725 Entire home/apt False       False        4.0              3.1044889325921967
#
#                                                                                             rest_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 lng
# 0.0    250.5668139214174  Entire home/apt False       False        3.0                          16.365
# 1.0    156.60425870088588 Entire home/apt False       False        3.0              16.333560000000002
# 2.0    283.0563541593624  Entire home/apt False       False        5.0                          16.336
# 3.0    301.75537012364725 Entire home/apt False       False        4.0                        16.33006
#
#                                                                                        rest_index_norm
# NaN    realSum            room_type       room_shared room_private person_capacity                 lat
# 0.0    250.5668139214174  Entire home/apt False       False        3.0                          48.223
# 1.0    156.60425870088588 Entire home/apt False       False        3.0                        48.17459
# 2.0    283.0563541593624  Entire home/apt False       False        5.0              48.211000000000006
# 3.0    301.75537012364725 Entire home/apt False       False        4.0                        48.20921
#
#                                                                                               realSum  \
# NaN    realSum            room_type       room_shared room_private person_capacity  host_is_superhost
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                           True
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                           True
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                           True
# 3.0    107.75307949419162 Private room    False       True         2.0                          False
#
#                                                                                    room_type  \
# NaN    realSum            room_type       room_shared room_private person_capacity     multi
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                     0
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                     0
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                     0
# 3.0    107.75307949419162 Private room    False       True         2.0                     0
#
#                                                                                    room_shared  \
# NaN    realSum            room_type       room_shared room_private person_capacity         biz
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                       1
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                       1
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                       1
# 3.0    107.75307949419162 Private room    False       True         2.0                       0
#
#                                                                                           room_private  \
# NaN    realSum            room_type       room_shared room_private person_capacity  cleanliness_rating
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                            10.0
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                            10.0
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                             9.0
# 3.0    107.75307949419162 Private room    False       True         2.0                             8.0
#
#                                                                                                person_capacity  \
# NaN    realSum            room_type       room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                                    94.0
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                                    96.0
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                                    91.0
# 3.0    107.75307949419162 Private room    False       True         2.0                                    92.0
#
#                                                                                    host_is_superhost  \
# NaN    realSum            room_type       room_shared room_private person_capacity          bedrooms
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                             2
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                             1
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                             1
# 3.0    107.75307949419162 Private room    False       True         2.0                             1
#
#                                                                                    multi biz cleanliness_rating  \
# NaN    realSum            room_type       room_shared room_private person_capacity                         dist
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                       3.2406127822783066
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                        2.241125849346171
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                        2.371551100164944
# 3.0    107.75307949419162 Private room    False       True         2.0                        3.629114002347827
#
#                                                                                    guest_satisfaction_overall  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 metro_dist
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                     0.6104497999388476
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                     1.1195048219502703
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                     0.4524186732395443
# 3.0    107.75307949419162 Private room    False       True         2.0                     0.4731636571848503
#
#                                                                                          bedrooms dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity          attr_index
# 0.0    324.66166467989626 Entire home/apt False       False        4.0               92.47346734746488
# 1.0    150.76081621204685 Entire home/apt False       False        2.0              124.25800230428001
# 2.0    196.33966762499125 Entire home/apt False       False        3.0              125.41312749902326
# 3.0    107.75307949419162 Private room    False       True         2.0                62.4594160025326
#
#                                                                                            metro_dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity    attr_index_norm
# 0.0    324.66166467989626 Entire home/apt False       False        4.0              6.622339573043595
# 1.0    150.76081621204685 Entire home/apt False       False        2.0               8.89853824594947
# 2.0    196.33966762499125 Entire home/apt False       False        3.0               8.98126069065055
# 3.0    107.75307949419162 Private room    False       True         2.0              4.472931254416767
#
#                                                                                             attr_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity          rest_index
# 0.0    324.66166467989626 Entire home/apt False       False        4.0              129.86287970210918
# 1.0    150.76081621204685 Entire home/apt False       False        2.0              154.35032224645815
# 2.0    196.33966762499125 Entire home/apt False       False        3.0               206.6424939586824
# 3.0    107.75307949419162 Private room    False       True         2.0               93.81071388306057
#
#                                                                                        attr_index_norm  \
# NaN    realSum            room_type       room_shared room_private person_capacity     rest_index_norm
# 0.0    324.66166467989626 Entire home/apt False       False        4.0              3.1387356979559917
# 1.0    150.76081621204685 Entire home/apt False       False        2.0              3.7305877363668265
# 2.0    196.33966762499125 Entire home/apt False       False        3.0              4.9944693509845015
# 3.0    107.75307949419162 Private room    False       True         2.0              2.2673687599637886
#
#                                                                                    rest_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity        lng
# 0.0    324.66166467989626 Entire home/apt False       False        4.0               16.33006
# 1.0    150.76081621204685 Entire home/apt False       False        2.0               16.38867
# 2.0    196.33966762499125 Entire home/apt False       False        3.0               16.34236
# 3.0    107.75307949419162 Private room    False       True         2.0               16.37837
#
#                                                                                    rest_index_norm
# NaN    realSum            room_type       room_shared room_private person_capacity             lat
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                    48.20921
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                    48.19104
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                    48.20436
# 3.0    107.75307949419162 Private room    False       True         2.0                    48.24102

# %%
import numpy as np

# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#                                                                                               realSum  \
# NaN    realSum            room_type       room_shared room_private person_capacity  host_is_superhost
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                           True
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                           True
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                           True
# 3.0    107.75307949419162 Private room    False       True         2.0                          False
#
#                                                                                    room_type  \
# NaN    realSum            room_type       room_shared room_private person_capacity     multi
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                     0
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                     0
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                     0
# 3.0    107.75307949419162 Private room    False       True         2.0                     0
#
#                                                                                    room_shared  \
# NaN    realSum            room_type       room_shared room_private person_capacity         biz
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                       1
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                       1
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                       1
# 3.0    107.75307949419162 Private room    False       True         2.0                       0
#
#                                                                                           room_private  \
# NaN    realSum            room_type       room_shared room_private person_capacity  cleanliness_rating
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                            10.0
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                            10.0
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                             9.0
# 3.0    107.75307949419162 Private room    False       True         2.0                             8.0
#
#                                                                                                person_capacity  \
# NaN    realSum            room_type       room_shared room_private person_capacity  guest_satisfaction_overall
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                                    94.0
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                                    96.0
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                                    91.0
# 3.0    107.75307949419162 Private room    False       True         2.0                                    92.0
#
#                                                                                    host_is_superhost  \
# NaN    realSum            room_type       room_shared room_private person_capacity          bedrooms
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                             2
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                             1
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                             1
# 3.0    107.75307949419162 Private room    False       True         2.0                             1
#
#                                                                                    multi biz cleanliness_rating  \
# NaN    realSum            room_type       room_shared room_private person_capacity                         dist
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                       3.2406127822783066
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                        2.241125849346171
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                        2.371551100164944
# 3.0    107.75307949419162 Private room    False       True         2.0                        3.629114002347827
#
#                                                                                    guest_satisfaction_overall  \
# NaN    realSum            room_type       room_shared room_private person_capacity                 metro_dist
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                     0.6104497999388476
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                     1.1195048219502703
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                     0.4524186732395443
# 3.0    107.75307949419162 Private room    False       True         2.0                     0.4731636571848503
#
#                                                                                          bedrooms dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity          attr_index
# 0.0    324.66166467989626 Entire home/apt False       False        4.0               92.47346734746488
# 1.0    150.76081621204685 Entire home/apt False       False        2.0              124.25800230428001
# 2.0    196.33966762499125 Entire home/apt False       False        3.0              125.41312749902326
# 3.0    107.75307949419162 Private room    False       True         2.0                62.4594160025326
#
#                                                                                            metro_dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity    attr_index_norm
# 0.0    324.66166467989626 Entire home/apt False       False        4.0              6.622339573043595
# 1.0    150.76081621204685 Entire home/apt False       False        2.0               8.89853824594947
# 2.0    196.33966762499125 Entire home/apt False       False        3.0               8.98126069065055
# 3.0    107.75307949419162 Private room    False       True         2.0              4.472931254416767
#
#                                                                                             attr_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity          rest_index
# 0.0    324.66166467989626 Entire home/apt False       False        4.0              129.86287970210918
# 1.0    150.76081621204685 Entire home/apt False       False        2.0              154.35032224645815
# 2.0    196.33966762499125 Entire home/apt False       False        3.0               206.6424939586824
# 3.0    107.75307949419162 Private room    False       True         2.0               93.81071388306057
#
#                                                                                        attr_index_norm  \
# NaN    realSum            room_type       room_shared room_private person_capacity     rest_index_norm
# 0.0    324.66166467989626 Entire home/apt False       False        4.0              3.1387356979559917
# 1.0    150.76081621204685 Entire home/apt False       False        2.0              3.7305877363668265
# 2.0    196.33966762499125 Entire home/apt False       False        3.0              4.9944693509845015
# 3.0    107.75307949419162 Private room    False       True         2.0              2.2673687599637886
#
#                                                                                    rest_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity        lng
# 0.0    324.66166467989626 Entire home/apt False       False        4.0               16.33006
# 1.0    150.76081621204685 Entire home/apt False       False        2.0               16.38867
# 2.0    196.33966762499125 Entire home/apt False       False        3.0               16.34236
# 3.0    107.75307949419162 Private room    False       True         2.0               16.37837
#
#                                                                                    rest_index_norm
# NaN    realSum            room_type       room_shared room_private person_capacity             lat
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                    48.20921
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                    48.19104
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                    48.20436
# 3.0    107.75307949419162 Private room    False       True         2.0                    48.24102

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#                                                                                     realSum  \
# NaN    realSum            room_type       room_shared room_private person_capacity    False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                False
# 3.0    107.75307949419162 Private room    False       True         2.0                False
#
#                                                                                     room_type  \
# NaN    realSum            room_type       room_shared room_private person_capacity      False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                  False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                  False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                  False
# 3.0    107.75307949419162 Private room    False       True         2.0                  False
#
#                                                                                     room_shared  \
# NaN    realSum            room_type       room_shared room_private person_capacity        False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                    False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                    False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                    False
# 3.0    107.75307949419162 Private room    False       True         2.0                    False
#
#                                                                                     room_private  \
# NaN    realSum            room_type       room_shared room_private person_capacity         False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                     False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                     False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                     False
# 3.0    107.75307949419162 Private room    False       True         2.0                     False
#
#                                                                                     person_capacity  \
# NaN    realSum            room_type       room_shared room_private person_capacity            False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                        False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                        False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                        False
# 3.0    107.75307949419162 Private room    False       True         2.0                        False
#
#                                                                                     host_is_superhost  \
# NaN    realSum            room_type       room_shared room_private person_capacity              False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                          False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                          False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                          False
# 3.0    107.75307949419162 Private room    False       True         2.0                          False
#
#                                                                                     multi biz cleanliness_rating  \
# NaN    realSum            room_type       room_shared room_private person_capacity                         False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                                     False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                                     False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                                     False
# 3.0    107.75307949419162 Private room    False       True         2.0                                     False
#
#                                                                                     guest_satisfaction_overall  \
# NaN    realSum            room_type       room_shared room_private person_capacity                       False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                                   False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                                   False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                                   False
# 3.0    107.75307949419162 Private room    False       True         2.0                                   False
#
#                                                                                     bedrooms dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity          False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                      False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                      False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                      False
# 3.0    107.75307949419162 Private room    False       True         2.0                      False
#
#                                                                                     metro_dist  \
# NaN    realSum            room_type       room_shared room_private person_capacity       False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                   False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                   False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                   False
# 3.0    107.75307949419162 Private room    False       True         2.0                   False
#
#                                                                                     attr_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity       False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                   False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                   False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                   False
# 3.0    107.75307949419162 Private room    False       True         2.0                   False
#
#                                                                                     attr_index_norm  \
# NaN    realSum            room_type       room_shared room_private person_capacity            False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                        False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                        False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                        False
# 3.0    107.75307949419162 Private room    False       True         2.0                        False
#
#                                                                                     rest_index  \
# NaN    realSum            room_type       room_shared room_private person_capacity       False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                   False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                   False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                   False
# 3.0    107.75307949419162 Private room    False       True         2.0                   False
#
#                                                                                     rest_index_norm
# NaN    realSum            room_type       room_shared room_private person_capacity            False
# 0.0    324.66166467989626 Entire home/apt False       False        4.0                        False
# 1.0    150.76081621204685 Entire home/apt False       False        2.0                        False
# 2.0    196.33966762499125 Entire home/apt False       False        3.0                        False
# 3.0    107.75307949419162 Private room    False       True         2.0                        False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# realSum
# False    1800
# Name: realSum, dtype: int64
#
# room_type
# False    1800
# Name: room_type, dtype: int64
#
# room_shared
# False    1800
# Name: room_shared, dtype: int64
#
# room_private
# False    1800
# Name: room_private, dtype: int64
#
# person_capacity
# False    1800
# Name: person_capacity, dtype: int64
#
# host_is_superhost
# False    1800
# Name: host_is_superhost, dtype: int64
#
# multi biz cleanliness_rating
# False    1800
# Name: multi biz cleanliness_rating, dtype: int64
#
# guest_satisfaction_overall
# False    1800
# Name: guest_satisfaction_overall, dtype: int64
#
# bedrooms dist
# False    1800
# Name: bedrooms dist, dtype: int64
#
# metro_dist
# False    1800
# Name: metro_dist, dtype: int64
#
# attr_index
# False    1800
# Name: attr_index, dtype: int64
#
# attr_index_norm
# False    1800
# Name: attr_index_norm, dtype: int64
#
# rest_index
# False    1800
# Name: rest_index, dtype: int64
#
# rest_index_norm
# False    1800
# Name: rest_index_norm, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0              2.0              False      1    0                10.0
# 1              4.0              False      0    0                 8.0
# 2              2.0              False      0    1                 9.0
# 3              4.0              False      0    1                 9.0
# 4              2.0               True      0    0                10.0
#
#    guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# 0                        93.0         1  5.022964    2.539380   78.690379
# 1                        85.0         1  0.488389    0.239404  631.176378
# 2                        87.0         1  5.748312    3.651621   75.275877
# 3                        90.0         2  0.384862    0.439876  493.272534
# 4                        98.0         1  0.544738    0.318693  552.830324
#
#    attr_index_norm  rest_index  rest_index_norm      lng       lat
# 0         4.166708   98.253896         6.846473  4.90569  52.41772
# 1        33.421209  837.280757        58.342928  4.90005  52.37432
# 2         3.985908   95.386955         6.646700  4.97512  52.36103
# 3        26.119108  875.033098        60.973565  4.89417  52.37663
# 4        29.272733  815.305740        56.811677  4.90051  52.37508
